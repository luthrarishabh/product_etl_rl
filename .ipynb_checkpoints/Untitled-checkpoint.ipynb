# %%
# Authentication
import boto3
import csv

# get a handle on s3
session = boto3.Session(
                    aws_access_key_id='AKIASL5PJBWMB5OFMUO4',
                    aws_secret_access_key='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',region_name = 'ca-central-1')
s3 = session.resource('s3')

# %%
Access key ID: AKIASL5PJBWMB5OFMUO4 
Secret access key: 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
# Out:
#   File "<ipython-input-68-d77974f2069f>", line 1
#     Access key ID: AKIASL5PJBWMKNUMYTBQ
#              ^
# SyntaxError: invalid syntax

# %%
# Downloading
import os
def download_s3_folder(bucket_name, s3_folder, local_dir=None):
    """
    Download the contents of a folder directory
    Args:
        bucket_name: the name of the s3 bucket
        s3_folder: the folder path in the s3 bucket
        local_dir: a relative or absolute directory path in the local file system
    """
    bucket = s3.Bucket(bucket_name)
    for obj in bucket.objects.filter(Prefix = s3_folder):
        target = obj.key if local_dir is None \
            else os.path.join(local_dir, os.path.basename(obj.key))
        if not os.path.exists(os.path.dirname(target)):
            os.makedirs(os.path.dirname(target))
        if 'json' in obj.key:
            bucket.download_file(obj.key, target)

# %%
download_s3_folder('flashfood-engineering-assessment-data','ff-2020-03-dat-eng','data')

# %%
# merging the data

from os import listdir
from os.path import isfile, join
df2 = pd.DataFrame()
i = 1
for f in listdir('data'):
    if 'json' in f:
        print(f)
        print(i)
        i = i+1
        df2 = pd.concat([df2, pd.read_json('data/' + f)])
# Out:
# ff__uCUudYizxwjqGBXlhBTzytQVXjXktJ3q--store_mapping_docs__2020-03-09 16:40:19.152445.json.gz
# 1
# ff__TgRqr7JusNrT9UNuLSKALqToRZecN2MR--store_mapping_docs__2020-03-09 16:37:57.115116.json.gz
# 2
# ff__RYtvZDcVudT9goIsXBWxgxGq1FDJGIvp--store_mapping_docs__2020-03-09 18:37:22.690090.json.gz
# 3
# ff__EyHdhAgBAGA5ZlrfswZ8ZPq6OqBkyPBJ--store_mapping_docs__2020-03-09 18:39:07.623293.json.gz
# 4
# ff__0fgVRpSB3YGGSV4ikG546xyXICRpNFhC--store_mapping_docs__2020-03-09 16:35:33.854812.json.gz
# 5
# ff__xx1Z6GJ6UzvGbnfCgaETNJqyGykWkVx7--store_mapping_docs__2020-03-09 16:35:50.385376.json.gz
# 6
# ff__WUFp1dAxCiez880XYBCxUhaC8efV2nNs--store_mapping_docs__2020-03-09 16:38:02.300533.json.gz
# 7
# ff__MlyrRmp1czsqghLA7a3vci1BKvUM2JS6--store_mapping_docs__2020-03-09 16:39:34.313655.json.gz
# 8
# ff__gJ6pEsMxHozzUL3MkDU4n27qTCqdT8UW--store_mapping_docs__2020-03-09 16:38:02.538414.json.gz
# 9
# ff__eMq1oT3pV3kiCgrx2tYdmBInRWHOIsBz--store_mapping_docs__2020-03-09 16:38:05.220427.json.gz
# 10
# ...

# %%
df3 = df2.reset_index().drop('index', 1)

# %%
df3
# Out:
#                   upc           name            category store_number price  \
# 0        887961520156      paceboard  Refrigerated Dough         1002 80.61
# 1        887961520163    transarctic            Diabetic         1009 10.87
# 2        887961520262  complexionist  Condiments-Ketchup         1005 30.77
# 3        887961521702          shove              Liquor         1002 44.31
# 4        887961522358     sunsetting  Tobacco-Cigarettes         1003 62.19
# ...               ...            ...                 ...          ...   ...
# 4939995   60383748248        schepel       Poultry-Fresh         1002 40.51
# 4939996   60383749405    cockscombed   Produce-Mushrooms         1009 73.73
# 4939997   60383749412       disprize            Baby HBC         1007 54.79
# 4939998   60383749570          Sinto             Gelatin         1006 77.83
# 4939999   60383749573     Brahmanize  Butter & Margarine         1005 52.84
#
# ...

# %%
tableName   = "lmt_tb_products"

dataFrame   = df3

# %%
from sqlalchemy import create_engine

import pymysql

sqlEngine       = create_engine('mysql+pymysql://root:Canadaforever1!@127.0.0.1/product_etl', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:

    frame           = dataFrame.to_sql(tableName, dbConnection, if_exists='fail');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:

    print("Table %s created successfully."%tableName);
# Out:
# Table lmt_tb_products created successfully.

# %%
print(int('00012914720141'))
# Out:
# 12914720141

# %%
# re.findall(r'^[A-Za-z0-9_.]+$', 'hello')
import re

len(re.findall(r'^[A-Za-z_.]+$', '1234'))
# Out:
# 0

# %%
len('60383748248')
# Out:
# 11

# %%
df2.upc
# Out:
# 0      887961520156
# 1      887961520163
# 2      887961520262
# 3      887961521702
# 4      887961522358
#            ...
# 995     60383748248
# 996     60383749405
# 997     60383749412
# 998     60383749570
# 999     60383749573
# Name: upc, Length: 4940000, dtype: object

# %%
# Out:
# 0     887961550848.00
# 1     887961550848.00
# 2     887961550848.00
# 3     887961550848.00
# 4     887961550848.00
#             ...
# 995    60383748096.00
# 996    60383748096.00
# 997    60383748096.00
# 998    60383748096.00
# 999    60383748096.00
# Name: upc, Length: 4940000, dtype: float32

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df3['price'] = df3.price.astype('str').apply(lambda x: np.nan if len(re.findall(r'^[A-Za-z_.]+$', x)) != 0 else x).astype('float64')
df3['upc'] = df3.upc.astype('str').apply(lambda x: np.nan if len(re.findall(r'^[A-Za-z_.]+$', x)) != 0 else (np.nan if (x == '')  else x)).astype('float64')
df3['store_number'] = df3.store_number.astype('str').apply(lambda x: np.nan if len(re.findall(r'^[A-Za-z_.]+$', x)) != 0 else (np.nan if (x == '')  else x)).astype('float64')

# %%
tableName   = "pmt_tb_p
dataFrame   = df3

from sqlalchemy import create_engine

import pymysql

sqlEngine       = create_engine('mysql+pymysql://root:Canadaforever1!@127.0.0.1/product_etl', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

try:

    frame           = dataFrame.to_sql(tableName, dbConnection, if_exists='fail');

except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)

else:
roducts"

    print("Table %s created successfully."%tableName);
# Out:
# Table pmt_tb_products created successfully.

# %%
df3[df3.upc.isnull()]
# Out:
#                       upc             name           category  store_number  \
# 2000    30683010305481.00          waesome    Frozen Desserts           nan
# 2001    30683010305702.00        celiotomy  Deli Branded Case           nan
# 2002    30683010445002.00  cilioflagellate      Beverage-Milk           nan
# 2003    30683010606021.00          gluteus     Bakery-Muffins           nan
# 2004    30683010606045.00       unsanctify     Bakery-Muffins           nan
# ...                   ...              ...                ...           ...
# 4921995   743434005905.00       supravital            Eyeware           nan
# 4921996   743434005974.00           josser     Beverage-Cocoa           nan
# 4921997   743434006018.00           knived     Beverage-Water           nan
# 4921998   743434007206.00       unamicably     Tobacco-E Cigs           nan
# 4921999   743434007312.00         sweepdom           Cleaners           nan
#
# ...

# %%
import numpy as np
df4 = df3[((df3.price.astype(np.float64)) > 0 or df3.price != '') and
( store_number != '') and (upc != '') ].drop_duplicates(subset=['upc', 'store_number'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-7214dcba1c52> in <module>
#       1 import numpy as np
# ----> 2 df4 = df3[((df3.price.astype(int)) > 0 or df3.price != '') and
#       3 ( store_number != '') and (upc != '') ].drop_duplicates(subset=['upc', 'store_number'])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# ...

# %%
df4.shape
# Out:
# (1586509, 10)

# %%
df3[df3.upc == 10000001317500]
# Out:
#          index             upc              name  \
# 64439      439  10000001317500           uncrude
# 119439     439  10000001317500            gluish
# 219439     439  10000001317500          homonymy
# 544439     439  10000001317500         surrogate
# 743439     439  10000001317500         cynareous
# 862439     439  10000001317500          cubicity
# 1040439    439  10000001317500       Napoleonist
# 1433439    439  10000001317500              sasa
# 1906439    439  10000001317500     irrepleviable
# 1948439    439  10000001317500          penetral
# 2054439    439  10000001317500   promorphologist
# 2967439    439  10000001317500          capercut
# 3055439    439  10000001317500       convenience
# 3065439    439  10000001317500        cyatholith
# 3093439    439  10000001317500        unhearable
# 3437439    439  10000001317500          diaspore
# 3457439    439  10000001317500       proterogyny
# 3510439    439  10000001317500        subbrigade
# ...

# %%
df2.shape
# Out:
# (4940000, 9)

# %%
bucket = s3.Bucket('flashfood-engineering-assessment-data')

# %%
obj = bucket.Object(key='ff-2020-03-dat-eng/ff__zxixKBqIVebLKPl2a5aolfcTQ0suv9of--store_mapping_docs__2020-03-09 16:34:00.562761.json.gz')

# %%
response = obj.get()

# read the contents of the file

# %%
s3 = boto3.resource(
    service_name='s3',
    aws_access_key_id='AKIASL5PJBWMKNUMYTBQ',
    aws_secret_access_key='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')

# %%
client = boto3.client(
    's3',
    aws_access_key_id = 'AKIASL5PJBWMB5OFMUO4',
    aws_secret_access_key = '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',
    region_name = 'ca-central-1'
)

# %%
Access key ID: AKIASL5PJBWMB5OFMUO4 
Secret access key: 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
# Out:
#   File "<ipython-input-81-d77974f2069f>", line 1
#     Access key ID: AKIASL5PJBWMKNUMYTBQ
#              ^
# SyntaxError: invalid syntax

# %%
clientResponse = client.list_buckets()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# ...

# %%
obj = client.get_object(
    Bucket = 'flashfood-engineering-assessment-data',
    Key = 'ff-2020-03-dat-eng/ff__zxixKBqIVebLKPl2a5aolfcTQ0suv9of--store_mapping_docs__2020-03-09 16:34:00.562761.json.gz'
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-47-d29adfb9a385> in <module>
#       1 obj = client.get_object(
#       2     Bucket = 'flashfood-engineering-assessment-data',
# ----> 3     Key = 'ff-2020-03-dat-eng/ff__zxixKBqIVebLKPl2a5aolfcTQ0suv9of--store_mapping_docs__2020-03-09 16:34:00.562761.json.gz'
#       4 )
#
# /anaconda3/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# /anaconda3/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
# ...

# %%
client = boto3.client(
    's3',
    aws_access_key_id = 'AKIA46SFIWN5AMWMDQVB',
    aws_secret_access_key = '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',
    region_name = 'ca-central-1'
)

# %%
clientResponse = client.list_buckets()
    
# Print the bucket names one by one
print('Printing bucket names...')
for bucket in clientResponse['Buckets']:
    print(f'Bucket Name: {bucket["Name"]}')
# Out:
# Printing bucket names...
# Bucket Name: sam-sls-demo
# Bucket Name: sql-server-shack-demo-1
# Bucket Name: sql-server-shack-demo-2
# Bucket Name: sql-server-shack-demo-3
# Bucket Name: sql-server-shack-demo-5

# %%
obj = client.get_object(
    Bucket = 'sql-server-shack-demo-1',
    Key = 'sql-shack-demo.csv'
)
    
# Read data from the S3 object
import pandas as pd
data = pd.read_csv(obj['Body'])
    
# Print the data frame
print('Printing the data frame...')
print(data)
# Out:
# Printing the data frame...
#    Name  Age
# 0   Bob   30
# 1  Dave   35
# 2   Tom   40
